# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
specdata1 = pd.read_csv("SN2022hrs_muv_20220422.4_50.dat", delim_whitespace="True", header=None, names=["wave","flux"])

specdata2 = pd.read_csv("SN2022hrs_muv_20220426.3_20.dat", delim_whitespace="True", header=None, names=["wave","flux"])

specdata3 = pd.read_csv("SN2022hrs_muv_20220506.9_20.dat", delim_whitespace="True", header=None, names=["wave","flux"])

specdata4 = pd.read_csv("SN2022hrs_muv_20220514.9_20.dat", delim_whitespace="True", header=None, names=["wave","flux"])

#print(specdata1["wave"])

# %%
plt.rcParams['figure.figsize'] = [15, 12]
plt.rcParams.update({'font.size': 22})

plt.plot(specdata1["wave"],specdata1["flux"], 'r', label='Apr 22', color='maroon')

plt.plot(specdata2["wave"],specdata2["flux"], 'r', label='Apr 26/27', color='red')

plt.plot(specdata3["wave"],specdata3["flux"], 'r', label='May 7', color='green')

plt.plot(specdata4["wave"],specdata4["flux"], 'r', label='May 15', color='blue')

plt.xlim([1600,6000])
plt.xlabel('Wavelength')
#plt.ylim([1.00*10.0**(-15.0),2.5*10.0**(-15.0)])


plt.ylabel('Flux')
plt.title(' ')
plt.legend()
plt.show()
# Out:
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_34774/921930637.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(specdata1["wave"],specdata1["flux"], 'r', label='Apr 22', color='maroon')
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_34774/921930637.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(specdata2["wave"],specdata2["flux"], 'r', label='Apr 26/27', color='red')
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_34774/921930637.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
# ...

# %%
plt.rcParams['figure.figsize'] = [15, 9]
plt.rcParams.update({'font.size': 22})

plt.plot(specdata1["wave"],specdata1["flux"], 'r', label='Apr 22', color='maroon')

plt.plot(specdata2["wave"],specdata2["flux"], 'r', label='Apr 26/27', color='red')

plt.plot(specdata3["wave"],specdata3["flux"], 'r', label='May 7', color='green')

plt.plot(specdata4["wave"],specdata4["flux"], 'r', label='May 15', color='blue')

plt.xlim([1600,6000])
plt.xlabel('Wavelength')
#plt.ylim([1.00*10.0**(-19.0),1.0*10.0**(-13.0)])
plt.yscale('log',base=10) 


plt.ylabel('Flux')
plt.title(' ')
plt.legend()
plt.show()
# Out:
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_34774/3024435035.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(specdata1["wave"],specdata1["flux"], 'r', label='Apr 22', color='maroon')
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_34774/3024435035.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(specdata2["wave"],specdata2["flux"], 'r', label='Apr 26/27', color='red')
# /var/folders/lm/1s7yhzbn56l3gt6dp_gzhtgc0000gn/T/ipykernel_34774/3024435035.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
# ...
